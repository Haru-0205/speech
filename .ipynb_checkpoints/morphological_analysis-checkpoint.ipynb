# %%
f = open('lyrics2.txt', 'r', encoding='utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# ねえ 女の子になりたい
# お願いいいですか?
#
# チョコレートの森をくぐる
# オレンジかぼちゃの馬車に
# 乗せられて 連れられて
# ミルク色のお城
#
# みんなきっと憧れている
# 童話の中のヒロイン
# いつか見た 夢に見た
# ガラスのハイヒール
#
# ナイショの気持ち ホントの気持ち
# ちょっと話しちゃおう
# ワンツースリー 魔法をかけて
# 新しいボクになりたいのです お願い!
#
# やっぱりボクも可愛くなりたいな
# あの子みたく可愛くなりたいな
# フリルドレスを召しませ
# 世界でひとりのシンデレラ
#
# ちっちゃなユウキとおっきなハジメテ
# きっと怖くなって震えちゃうけど
# 女の子になりたい!
# お願いいいですか?
# 可愛くなっていいですか?
#
# 大人になれど下がらない
# 可笑しな声のトーンと
# 何しても 何しても
# うまくいかない今日だ
#
# ならば!
# 束の間でも夢の中に
# ボクを見つけてみようかな
# 少しだけ 少しだけ
# 変われる気がする
#
# ドキドキして ドキドキして
# 眠れない夜
# ワンツースリー 勇気を出せば
# 童話に続く入口はもうそこだよ
#
# 上目遣いで太陽が昇って
# ウィンクのひとつで喧嘩が収まる
# 小さなリボン結んだら
# 世界もひとつに シンデレラ
#
# 花も照れて恥ずかしがるような
# もう少し君をひとり占めできるような
# 女の子になりたい!
# 隣にいいですか?
#
# 当たり前のものどれもが
# 違って見えたんだ
# ワンツースリー 魔法をかけて
# 新しいボクになりたいのです お願い!
#
# やっぱりボクも可愛くなりたいな
# あの子みたく可愛くなりたいな
# 小さく首を傾げたら
# ボクも今だけはシンデレラ
#
# 大事な今日を隅っこに隠れて
# 自分のこともわかんなくなる前に
# 女の子になりたい!
# お願いいいですか?
# 可愛くなっていいですか?
#
# ナイショだよ

# %%
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
print(data.splitlines)
# Out:
# <built-in method splitlines of str object at 0x00000298CE874410>

# %%
print(data)
# Out:
# ねえ 女の子になりたい
# お願いいいですか?
#
# チョコレートの森をくぐる
# オレンジかぼちゃの馬車に
# 乗せられて 連れられて
# ミルク色のお城
#
# みんなきっと憧れている
# 童話の中のヒロイン
# いつか見た 夢に見た
# ガラスのハイヒール
#
# ナイショの気持ち ホントの気持ち
# ちょっと話しちゃおう
# ワンツースリー 魔法をかけて
# 新しいボクになりたいのです お願い!
#
# やっぱりボクも可愛くなりたいな
# あの子みたく可愛くなりたいな
# フリルドレスを召しませ
# 世界でひとりのシンデレラ
#
# ちっちゃなユウキとおっきなハジメテ
# きっと怖くなって震えちゃうけど
# 女の子になりたい!
# お願いいいですか?
# 可愛くなっていいですか?
#
# 大人になれど下がらない
# 可笑しな声のトーンと
# 何しても 何しても
# うまくいかない今日だ
#
# ならば!
# 束の間でも夢の中に
# ボクを見つけてみようかな
# 少しだけ 少しだけ
# 変われる気がする
#
# ドキドキして ドキドキして
# 眠れない夜
# ワンツースリー 勇気を出せば
# 童話に続く入口はもうそこだよ
#
# 上目遣いで太陽が昇って
# ウィンクのひとつで喧嘩が収まる
# 小さなリボン結んだら
# 世界もひとつに シンデレラ
#
# 花も照れて恥ずかしがるような
# もう少し君をひとり占めできるような
# 女の子になりたい!
# 隣にいいですか?
#
# 当たり前のものどれもが
# 違って見えたんだ
# ワンツースリー 魔法をかけて
# 新しいボクになりたいのです お願い!
#
# やっぱりボクも可愛くなりたいな
# あの子みたく可愛くなりたいな
# 小さく首を傾げたら
# ボクも今だけはシンデレラ
#
# 大事な今日を隅っこに隠れて
# 自分のこともわかんなくなる前に
# 女の子になりたい!
# お願いいいですか?
# 可愛くなっていいですか?
#
# ナイショだよ

# %%
from janome.tokenizer import Tokenizer

# %%
t = Tokenizer()

# %%
for token in t.tokenize(data):
    print(token)
# Out:
# ねえ	感動詞,*,*,*,*,*,ねえ,ネエ,ネー
#  	記号,空白,*,*,*,*, ,*,*
# 女の子	名詞,一般,*,*,*,*,女の子,オンナノコ,オンナノコ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# お願い	名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ?	名詞,サ変接続,*,*,*,*,?,*,*
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# チョコレート	名詞,一般,*,*,*,*,チョコレート,チョコレート,チョコレート
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 森	名詞,一般,*,*,*,*,森,モリ,モリ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# くぐる	動詞,自立,*,*,五段・ラ行,基本形,くぐる,クグル,クグル
#
# 	記号,空白,*,*,*,*,
# ,*,*
# オレンジ	名詞,一般,*,*,*,*,オレンジ,オレンジ,オレンジ
# かぼちゃ	名詞,一般,*,*,*,*,かぼちゃ,カボチャ,カボチャ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 馬車	名詞,一般,*,*,*,*,馬車,バシャ,バシャ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 乗せ	動詞,自立,*,*,一段,未然形,乗せる,ノセ,ノセ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
#  	記号,空白,*,*,*,*, ,*,*
# 連れ	動詞,自立,*,*,一段,未然形,連れる,ツレ,ツレ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ミルク	名詞,一般,*,*,*,*,ミルク,ミルク,ミルク
# 色	名詞,接尾,一般,*,*,*,色,ショク,ショク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 城	名詞,一般,*,*,*,*,城,シロ,シロ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# みんな	名詞,代名詞,一般,*,*,*,みんな,ミンナ,ミンナ
# きっと	副詞,一般,*,*,*,*,きっと,キット,キット
# 憧れ	動詞,自立,*,*,一段,連用形,憧れる,アコガレ,アコガレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 童話	名詞,一般,*,*,*,*,童話,ドウワ,ドーワ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ヒロイン	名詞,一般,*,*,*,*,ヒロイン,ヒロイン,ヒロイン
#
# 	記号,空白,*,*,*,*,
# ,*,*
# いつか	名詞,副詞可能,*,*,*,*,いつか,イツカ,イツカ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#  	記号,空白,*,*,*,*, ,*,*
# 夢	名詞,一般,*,*,*,*,夢,ユメ,ユメ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ガラス	名詞,一般,*,*,*,*,ガラス,ガラス,ガラス
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ハイヒール	名詞,一般,*,*,*,*,ハイヒール,ハイヒール,ハイヒール
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ナイショ	名詞,一般,*,*,*,*,ナイショ,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
#  	記号,空白,*,*,*,*, ,*,*
# ホント	名詞,一般,*,*,*,*,ホント,ホント,ホント
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ちょっと	副詞,助詞類接続,*,*,*,*,ちょっと,チョット,チョット
# 話し	動詞,自立,*,*,五段・サ行,連用形,話す,ハナシ,ハナシ
# ちゃお	動詞,非自立,*,*,五段・ワ行促音便,未然ウ接続,ちゃう,チャオ,チャオ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ワンツースリー	名詞,一般,*,*,*,*,ワンツースリー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 魔法	名詞,一般,*,*,*,*,魔法,マホウ,マホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# かけ	動詞,自立,*,*,一段,連用形,かける,カケ,カケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
#  	記号,空白,*,*,*,*, ,*,*
# お願い	名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ
# !	名詞,サ変接続,*,*,*,*,!,*,*
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# やっぱり	副詞,一般,*,*,*,*,やっぱり,ヤッパリ,ヤッパリ
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# あの	連体詞,*,*,*,*,*,あの,アノ,アノ
# 子	名詞,一般,*,*,*,*,子,コ,コ
# み	動詞,自立,*,*,一段,連用形,みる,ミ,ミ
# たく	助動詞,*,*,*,特殊・タイ,連用テ接続,たい,タク,タク
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# フリル	名詞,一般,*,*,*,*,フリル,フリル,フリル
# ドレス	名詞,一般,*,*,*,*,ドレス,ドレス,ドレス
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 召し	動詞,自立,*,*,五段・サ行,連用形,召す,メシ,メシ
# ませ	助動詞,*,*,*,特殊・マス,命令ｅ,ます,マセ,マセ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 世界	名詞,一般,*,*,*,*,世界,セカイ,セカイ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# ひとり	名詞,一般,*,*,*,*,ひとり,ヒトリ,ヒトリ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# シンデレラ	名詞,固有名詞,人名,一般,*,*,シンデレラ,シンデレラ,シンデレラ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ちっちゃな	連体詞,*,*,*,*,*,ちっちゃな,チッチャナ,チッチャナ
# ユウキ	名詞,一般,*,*,*,*,ユウキ,*,*
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# おっきな	連体詞,*,*,*,*,*,おっきな,オッキナ,オッキナ
# ハジメテ	名詞,一般,*,*,*,*,ハジメテ,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# きっと	副詞,一般,*,*,*,*,きっと,キット,キット
# 怖く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,怖い,コワク,コワク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 震え	動詞,自立,*,*,一段,連用形,震える,フルエ,フルエ
# ちゃう	動詞,非自立,*,*,五段・ワ行促音便,基本形,ちゃう,チャウ,チャウ
# けど	助詞,接続助詞,*,*,*,*,けど,ケド,ケド
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 女の子	名詞,一般,*,*,*,*,女の子,オンナノコ,オンナノコ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# !	名詞,サ変接続,*,*,*,*,!,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# お願い	名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ?	名詞,サ変接続,*,*,*,*,?,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いい	形容詞,非自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ?	名詞,サ変接続,*,*,*,*,?,*,*
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 大人	名詞,一般,*,*,*,*,大人,オトナ,オトナ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なれ	動詞,自立,*,*,五段・ラ行,仮定形,なる,ナレ,ナレ
# ど	助詞,接続助詞,*,*,*,*,ど,ド,ド
# 下がら	動詞,自立,*,*,五段・ラ行,未然形,下がる,サガラ,サガラ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 可笑し	形容詞,自立,*,*,形容詞・イ段,ガル接続,可笑しい,オカシ,オカシ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
# 声	名詞,一般,*,*,*,*,声,コエ,コエ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# トーン	名詞,一般,*,*,*,*,トーン,トーン,トーン
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
#  	記号,空白,*,*,*,*, ,*,*
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# うまく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,うまい,ウマク,ウマク
# いか	動詞,自立,*,*,五段・カ行促音便,未然形,いく,イカ,イカ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ならば	接続詞,*,*,*,*,*,ならば,ナラバ,ナラバ
# !	名詞,サ変接続,*,*,*,*,!,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 束の間	名詞,一般,*,*,*,*,束の間,ツカノマ,ツカノマ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 夢	名詞,一般,*,*,*,*,夢,ユメ,ユメ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 見つけ	動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# みよ	動詞,非自立,*,*,一段,未然ウ接続,みる,ミヨ,ミヨ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 少し	副詞,助詞類接続,*,*,*,*,少し,スコシ,スコシ
# だけ	助詞,副助詞,*,*,*,*,だけ,ダケ,ダケ
#  	記号,空白,*,*,*,*, ,*,*
# 少し	副詞,助詞類接続,*,*,*,*,少し,スコシ,スコシ
# だけ	助詞,副助詞,*,*,*,*,だけ,ダケ,ダケ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 変	名詞,形容動詞語幹,*,*,*,*,変,ヘン,ヘン
# われる	動詞,自立,*,*,一段,基本形,われる,ワレル,ワレル
# 気	名詞,非自立,一般,*,*,*,気,キ,キ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ドキドキ	名詞,サ変接続,*,*,*,*,ドキドキ,ドキドキ,ドキドキ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
#  	記号,空白,*,*,*,*, ,*,*
# ドキドキ	名詞,サ変接続,*,*,*,*,ドキドキ,ドキドキ,ドキドキ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 眠れ	動詞,自立,*,*,一段,未然形,眠れる,ネムレ,ネムレ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# 夜	名詞,副詞可能,*,*,*,*,夜,ヨル,ヨル
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ワンツースリー	名詞,一般,*,*,*,*,ワンツースリー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 勇気	名詞,一般,*,*,*,*,勇気,ユウキ,ユーキ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 出せ	動詞,自立,*,*,五段・サ行,仮定形,出す,ダセ,ダセ
# ば	助詞,接続助詞,*,*,*,*,ば,バ,バ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 童話	名詞,一般,*,*,*,*,童話,ドウワ,ドーワ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 続く	動詞,自立,*,*,五段・カ行イ音便,基本形,続く,ツヅク,ツズク
# 入口	名詞,一般,*,*,*,*,入口,イリグチ,イリグチ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# もう	副詞,一般,*,*,*,*,もう,モウ,モー
# そこ	名詞,代名詞,一般,*,*,*,そこ,ソコ,ソコ
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 上目遣い	名詞,一般,*,*,*,*,上目遣い,ウワメヅカイ,ウワメズカイ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 太陽	名詞,一般,*,*,*,*,太陽,タイヨウ,タイヨー
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 昇っ	動詞,自立,*,*,五段・ラ行,連用タ接続,昇る,ノボッ,ノボッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ウィンク	名詞,一般,*,*,*,*,ウィンク,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# ひとつ	名詞,副詞可能,*,*,*,*,ひとつ,ヒトツ,ヒトツ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# 喧嘩	名詞,サ変接続,*,*,*,*,喧嘩,ケンカ,ケンカ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 収まる	動詞,自立,*,*,五段・ラ行,基本形,収まる,オサマル,オサマル
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 小さな	連体詞,*,*,*,*,*,小さな,チイサナ,チーサナ
# リボン	名詞,一般,*,*,*,*,リボン,リボン,リボン
# 結ん	動詞,自立,*,*,五段・バ行,連用タ接続,結ぶ,ムスン,ムスン
# だら	助動詞,*,*,*,特殊・タ,仮定形,だ,ダラ,ダラ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 世界	名詞,一般,*,*,*,*,世界,セカイ,セカイ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# ひとつ	名詞,副詞可能,*,*,*,*,ひとつ,ヒトツ,ヒトツ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
#  	記号,空白,*,*,*,*, ,*,*
# シンデレラ	名詞,固有名詞,人名,一般,*,*,シンデレラ,シンデレラ,シンデレラ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 花	名詞,一般,*,*,*,*,花,ハナ,ハナ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 照れ	動詞,自立,*,*,一段,連用形,照れる,テレ,テレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 恥ずかし	形容詞,自立,*,*,形容詞・イ段,ガル接続,恥ずかしい,ハズカシ,ハズカシ
# がる	動詞,接尾,*,*,五段・ラ行,基本形,がる,ガル,ガル
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# もう少し	副詞,助詞類接続,*,*,*,*,もう少し,モウスコシ,モースコシ
# 君	名詞,代名詞,一般,*,*,*,君,キミ,キミ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# ひとり占め	名詞,サ変接続,*,*,*,*,ひとり占め,ヒトリジメ,ヒトリジメ
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 女の子	名詞,一般,*,*,*,*,女の子,オンナノコ,オンナノコ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# !	名詞,サ変接続,*,*,*,*,!,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 隣	名詞,一般,*,*,*,*,隣,トナリ,トナリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ?	名詞,サ変接続,*,*,*,*,?,*,*
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 当たり前	名詞,形容動詞語幹,*,*,*,*,当たり前,アタリマエ,アタリマエ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# もの	名詞,非自立,一般,*,*,*,もの,モノ,モノ
# どれ	名詞,代名詞,一般,*,*,*,どれ,ドレ,ドレ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 違っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,違う,チガッ,チガッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 見え	動詞,自立,*,*,一段,連用形,見える,ミエ,ミエ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ワンツースリー	名詞,一般,*,*,*,*,ワンツースリー,*,*
#  	記号,空白,*,*,*,*, ,*,*
# 魔法	名詞,一般,*,*,*,*,魔法,マホウ,マホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# かけ	動詞,自立,*,*,一段,連用形,かける,カケ,カケ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
#  	記号,空白,*,*,*,*, ,*,*
# お願い	名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ
# !	名詞,サ変接続,*,*,*,*,!,*,*
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# やっぱり	副詞,一般,*,*,*,*,やっぱり,ヤッパリ,ヤッパリ
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# あの	連体詞,*,*,*,*,*,あの,アノ,アノ
# 子	名詞,一般,*,*,*,*,子,コ,コ
# み	動詞,自立,*,*,一段,連用形,みる,ミ,ミ
# たく	助動詞,*,*,*,特殊・タイ,連用テ接続,たい,タク,タク
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# な	助詞,終助詞,*,*,*,*,な,ナ,ナ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 小さく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,小さい,チイサク,チーサク
# 首	名詞,一般,*,*,*,*,首,クビ,クビ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 傾げ	動詞,自立,*,*,一段,連用形,傾げる,カタゲ,カタゲ
# たら	助動詞,*,*,*,特殊・タ,仮定形,た,タラ,タラ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 今	名詞,副詞可能,*,*,*,*,今,イマ,イマ
# だけ	助詞,副助詞,*,*,*,*,だけ,ダケ,ダケ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# シンデレラ	名詞,固有名詞,人名,一般,*,*,シンデレラ,シンデレラ,シンデレラ
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# 大事	名詞,形容動詞語幹,*,*,*,*,大事,ダイジ,ダイジ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 隅っこ	名詞,一般,*,*,*,*,隅っこ,スミッコ,スミッコ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 隠れ	動詞,自立,*,*,一段,連用形,隠れる,カクレ,カクレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# わか	動詞,自立,*,*,五段・カ行イ音便,未然形,わく,ワカ,ワカ
# ん	助動詞,*,*,*,不変化型,基本形,ん,ン,ン
# なく	助動詞,*,*,*,特殊・ナイ,連用テ接続,ない,ナク,ナク
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# 前	名詞,副詞可能,*,*,*,*,前,マエ,マエ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 女の子	名詞,一般,*,*,*,*,女の子,オンナノコ,オンナノコ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
# たい	助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ
# !	名詞,サ変接続,*,*,*,*,!,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# お願い	名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ?	名詞,サ変接続,*,*,*,*,?,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いい	形容詞,非自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
# です	助動詞,*,*,*,特殊・デス,基本形,です,デス,デス
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# ?	名詞,サ変接続,*,*,*,*,?,*,*
#
#
# 	記号,空白,*,*,*,*,
#
# ,*,*
# ナイショ	名詞,一般,*,*,*,*,ナイショ,*,*
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# よ	助詞,終助詞,*,*,*,*,よ,ヨ,ヨ

# %%
lyrics = data.replace("\n", "")

# %%
print(lyrics)
# Out:
# ねえ 女の子になりたいお願いいいですか?チョコレートの森をくぐるオレンジかぼちゃの馬車に乗せられて 連れられてミルク色のお城みんなきっと憧れている童話の中のヒロインいつか見た 夢に見たガラスのハイヒールナイショの気持ち ホントの気持ちちょっと話しちゃおうワンツースリー 魔法をかけて新しいボクになりたいのです お願い!やっぱりボクも可愛くなりたいなあの子みたく可愛くなりたいなフリルドレスを召しませ世界でひとりのシンデレラちっちゃなユウキとおっきなハジメテきっと怖くなって震えちゃうけど女の子になりたい!お願いいいですか?可愛くなっていいですか?大人になれど下がらない可笑しな声のトーンと何しても 何してもうまくいかない今日だならば!束の間でも夢の中にボクを見つけてみようかな少しだけ 少しだけ変われる気がするドキドキして ドキドキして眠れない夜ワンツースリー 勇気を出せば童話に続く入口はもうそこだよ上目遣いで太陽が昇ってウィンクのひとつで喧嘩が収まる小さなリボン結んだら世界もひとつに シンデレラ花も照れて恥ずかしがるようなもう少し君をひとり占めできるような女の子になりたい!隣にいいですか?当たり前のものどれもが違って見えたんだワンツースリー 魔法をかけて新しいボクになりたいのです お願い!やっぱりボクも可愛くなりたいなあの子みたく可愛くなりたいな小さく首を傾げたらボクも今だけはシンデレラ大事な今日を隅っこに隠れて自分のこともわかんなくなる前に女の子になりたい!お願いいいですか?可愛くなっていいですか?ナイショだよ

# %%
lyrics = lyrics.replace(" ","")

# %%
print(lyrics)
# Out:
# ねえ女の子になりたいお願いいいですか?チョコレートの森をくぐるオレンジかぼちゃの馬車に乗せられて連れられてミルク色のお城みんなきっと憧れている童話の中のヒロインいつか見た夢に見たガラスのハイヒールナイショの気持ちホントの気持ちちょっと話しちゃおうワンツースリー魔法をかけて新しいボクになりたいのですお願い!やっぱりボクも可愛くなりたいなあの子みたく可愛くなりたいなフリルドレスを召しませ世界でひとりのシンデレラちっちゃなユウキとおっきなハジメテきっと怖くなって震えちゃうけど女の子になりたい!お願いいいですか?可愛くなっていいですか?大人になれど下がらない可笑しな声のトーンと何しても何してもうまくいかない今日だならば!束の間でも夢の中にボクを見つけてみようかな少しだけ少しだけ変われる気がするドキドキしてドキドキして眠れない夜ワンツースリー勇気を出せば童話に続く入口はもうそこだよ上目遣いで太陽が昇ってウィンクのひとつで喧嘩が収まる小さなリボン結んだら世界もひとつにシンデレラ花も照れて恥ずかしがるようなもう少し君をひとり占めできるような女の子になりたい!隣にいいですか?当たり前のものどれもが違って見えたんだワンツースリー魔法をかけて新しいボクになりたいのですお願い!やっぱりボクも可愛くなりたいなあの子みたく可愛くなりたいな小さく首を傾げたらボクも今だけはシンデレラ大事な今日を隅っこに隠れて自分のこともわかんなくなる前に女の子になりたい!お願いいいですか?可愛くなっていいですか?ナイショだよ

# %%
import re
words=[]

for token in t.tokenize(lyrics):
    if re.compile("^助詞").search(token.part_of_speech) or re.compile("^助動詞").search(token.part_of_speech):
        print("")
    else:
        words.append(token.base_form)
        print(token)
# Out:
# ねえ	感動詞,*,*,*,*,*,ねえ,ネエ,ネー
# 女の子	名詞,一般,*,*,*,*,女の子,オンナノコ,オンナノコ
#
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
#
# お願い	名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
#
#
# ?	名詞,サ変接続,*,*,*,*,?,*,*
# チョコレート	名詞,一般,*,*,*,*,チョコレート,チョコレート,チョコレート
#
# 森	名詞,一般,*,*,*,*,森,モリ,モリ
#
# くぐる	動詞,自立,*,*,五段・ラ行,基本形,くぐる,クグル,クグル
# オレンジ	名詞,一般,*,*,*,*,オレンジ,オレンジ,オレンジ
# かぼちゃ	名詞,一般,*,*,*,*,かぼちゃ,カボチャ,カボチャ
#
# 馬車	名詞,一般,*,*,*,*,馬車,バシャ,バシャ
#
# 乗せ	動詞,自立,*,*,一段,未然形,乗せる,ノセ,ノセ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
#
# 連れ	動詞,自立,*,*,一段,未然形,連れる,ツレ,ツレ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
#
# ミルク	名詞,一般,*,*,*,*,ミルク,ミルク,ミルク
# 色	名詞,接尾,一般,*,*,*,色,ショク,ショク
#
# お	接頭詞,名詞接続,*,*,*,*,お,オ,オ
# 城	名詞,一般,*,*,*,*,城,シロ,シロ
# みんな	名詞,代名詞,一般,*,*,*,みんな,ミンナ,ミンナ
# きっと	副詞,一般,*,*,*,*,きっと,キット,キット
# 憧れ	動詞,自立,*,*,一段,連用形,憧れる,アコガレ,アコガレ
#
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 童話	名詞,一般,*,*,*,*,童話,ドウワ,ドーワ
#
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
#
# ヒロイン	名詞,一般,*,*,*,*,ヒロイン,ヒロイン,ヒロイン
# いつか	名詞,副詞可能,*,*,*,*,いつか,イツカ,イツカ
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
#
# 夢	名詞,一般,*,*,*,*,夢,ユメ,ユメ
#
# 見	動詞,自立,*,*,一段,連用形,見る,ミ,ミ
#
# ガラス	名詞,一般,*,*,*,*,ガラス,ガラス,ガラス
#
# ハイヒールナイショ	名詞,一般,*,*,*,*,ハイヒールナイショ,*,*
#
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# ホント	名詞,一般,*,*,*,*,ホント,ホント,ホント
#
# 気持ち	名詞,一般,*,*,*,*,気持ち,キモチ,キモチ
# ちょっと	副詞,助詞類接続,*,*,*,*,ちょっと,チョット,チョット
# 話し	動詞,自立,*,*,五段・サ行,連用形,話す,ハナシ,ハナシ
# ちゃお	動詞,非自立,*,*,五段・ワ行促音便,未然ウ接続,ちゃう,チャオ,チャオ
#
# ワンツースリー	名詞,一般,*,*,*,*,ワンツースリー,*,*
# 魔法	名詞,一般,*,*,*,*,魔法,マホウ,マホー
#
# かけ	動詞,自立,*,*,一段,連用形,かける,カケ,カケ
#
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
#
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
#
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
#
# お願い	名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ
# !	名詞,サ変接続,*,*,*,*,!,*,*
# やっぱり	副詞,一般,*,*,*,*,やっぱり,ヤッパリ,ヤッパリ
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
#
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
#
#
# あの	フィラー,*,*,*,*,*,あの,アノ,アノ
# 子	名詞,一般,*,*,*,*,子,コ,コ
# み	動詞,自立,*,*,一段,連用形,みる,ミ,ミ
#
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
#
#
# フリル	名詞,一般,*,*,*,*,フリル,フリル,フリル
# ドレス	名詞,一般,*,*,*,*,ドレス,ドレス,ドレス
#
# 召し	動詞,自立,*,*,五段・サ行,連用形,召す,メシ,メシ
#
# 世界	名詞,一般,*,*,*,*,世界,セカイ,セカイ
#
# ひとり	名詞,一般,*,*,*,*,ひとり,ヒトリ,ヒトリ
#
# シンデレラ	名詞,固有名詞,人名,一般,*,*,シンデレラ,シンデレラ,シンデレラ
# ちっちゃな	連体詞,*,*,*,*,*,ちっちゃな,チッチャナ,チッチャナ
# ユウキ	名詞,一般,*,*,*,*,ユウキ,*,*
#
# おっきな	連体詞,*,*,*,*,*,おっきな,オッキナ,オッキナ
# ハジメテ	名詞,一般,*,*,*,*,ハジメテ,*,*
# きっと	副詞,一般,*,*,*,*,きっと,キット,キット
# 怖く	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,怖い,コワク,コワク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
#
# 震え	動詞,自立,*,*,一段,連用形,震える,フルエ,フルエ
# ちゃう	動詞,非自立,*,*,五段・ワ行促音便,基本形,ちゃう,チャウ,チャウ
#
# 女の子	名詞,一般,*,*,*,*,女の子,オンナノコ,オンナノコ
#
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
#
# !	名詞,サ変接続,*,*,*,*,!,*,*
# お願い	名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
#
#
# ?	名詞,サ変接続,*,*,*,*,?,*,*
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
#
# いい	形容詞,非自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
#
#
# ?	名詞,サ変接続,*,*,*,*,?,*,*
# 大人	名詞,一般,*,*,*,*,大人,オトナ,オトナ
#
# なれ	動詞,自立,*,*,五段・ラ行,仮定形,なる,ナレ,ナレ
#
# 下がら	動詞,自立,*,*,五段・ラ行,未然形,下がる,サガラ,サガラ
#
# 可笑し	形容詞,自立,*,*,形容詞・イ段,ガル接続,可笑しい,オカシ,オカシ
#
# 声	名詞,一般,*,*,*,*,声,コエ,コエ
#
# トーン	名詞,一般,*,*,*,*,トーン,トーン,トーン
#
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
#
#
# 何	名詞,代名詞,一般,*,*,*,何,ナニ,ナニ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
#
#
# うまく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,うまい,ウマク,ウマク
# いか	動詞,自立,*,*,五段・カ行促音便,未然形,いく,イカ,イカ
#
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
#
#
#
# !	名詞,サ変接続,*,*,*,*,!,*,*
# 束の間	名詞,一般,*,*,*,*,束の間,ツカノマ,ツカノマ
#
#
# 夢	名詞,一般,*,*,*,*,夢,ユメ,ユメ
#
# 中	名詞,非自立,副詞可能,*,*,*,中,ナカ,ナカ
#
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
#
# 見つけ	動詞,自立,*,*,一段,連用形,見つける,ミツケ,ミツケ
#
# みよ	動詞,非自立,*,*,一段,未然ウ接続,みる,ミヨ,ミヨ
#
#
#
# 少し	副詞,助詞類接続,*,*,*,*,少し,スコシ,スコシ
#
# 少し	副詞,助詞類接続,*,*,*,*,少し,スコシ,スコシ
#
# 変	名詞,形容動詞語幹,*,*,*,*,変,ヘン,ヘン
# われる	動詞,自立,*,*,一段,基本形,われる,ワレル,ワレル
# 気	名詞,非自立,一般,*,*,*,気,キ,キ
#
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# ドキドキ	名詞,サ変接続,*,*,*,*,ドキドキ,ドキドキ,ドキドキ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
#
# ドキドキ	名詞,サ変接続,*,*,*,*,ドキドキ,ドキドキ,ドキドキ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
#
# 眠れ	動詞,自立,*,*,一段,未然形,眠れる,ネムレ,ネムレ
#
# 夜	名詞,副詞可能,*,*,*,*,夜,ヨル,ヨル
# ワンツースリー	名詞,一般,*,*,*,*,ワンツースリー,*,*
# 勇気	名詞,一般,*,*,*,*,勇気,ユウキ,ユーキ
#
# 出せ	動詞,自立,*,*,五段・サ行,仮定形,出す,ダセ,ダセ
#
# 童話	名詞,一般,*,*,*,*,童話,ドウワ,ドーワ
#
# 続く	動詞,自立,*,*,五段・カ行イ音便,基本形,続く,ツヅク,ツズク
# 入口	名詞,一般,*,*,*,*,入口,イリグチ,イリグチ
#
# もう	副詞,一般,*,*,*,*,もう,モウ,モー
# そこ	名詞,代名詞,一般,*,*,*,そこ,ソコ,ソコ
#
#
# 上目遣い	名詞,一般,*,*,*,*,上目遣い,ウワメヅカイ,ウワメズカイ
#
# 太陽	名詞,一般,*,*,*,*,太陽,タイヨウ,タイヨー
#
# 昇っ	動詞,自立,*,*,五段・ラ行,連用タ接続,昇る,ノボッ,ノボッ
#
# ウィンク	名詞,一般,*,*,*,*,ウィンク,*,*
#
# ひとつ	名詞,副詞可能,*,*,*,*,ひとつ,ヒトツ,ヒトツ
#
# 喧嘩	名詞,サ変接続,*,*,*,*,喧嘩,ケンカ,ケンカ
#
# 収まる	動詞,自立,*,*,五段・ラ行,基本形,収まる,オサマル,オサマル
# 小さな	連体詞,*,*,*,*,*,小さな,チイサナ,チーサナ
# リボン	名詞,一般,*,*,*,*,リボン,リボン,リボン
# 結ん	動詞,自立,*,*,五段・バ行,連用タ接続,結ぶ,ムスン,ムスン
#
# 世界	名詞,一般,*,*,*,*,世界,セカイ,セカイ
#
# ひとつ	名詞,副詞可能,*,*,*,*,ひとつ,ヒトツ,ヒトツ
#
# シンデレラ	名詞,固有名詞,人名,一般,*,*,シンデレラ,シンデレラ,シンデレラ
# 花	名詞,一般,*,*,*,*,花,ハナ,ハナ
#
# 照れ	動詞,自立,*,*,一段,連用形,照れる,テレ,テレ
#
# 恥ずかし	形容詞,自立,*,*,形容詞・イ段,ガル接続,恥ずかしい,ハズカシ,ハズカシ
# がる	動詞,接尾,*,*,五段・ラ行,基本形,がる,ガル,ガル
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
#
# もう少し	副詞,助詞類接続,*,*,*,*,もう少し,モウスコシ,モースコシ
# 君	名詞,代名詞,一般,*,*,*,君,キミ,キミ
#
# ひとり占め	名詞,サ変接続,*,*,*,*,ひとり占め,ヒトリジメ,ヒトリジメ
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
#
# 女の子	名詞,一般,*,*,*,*,女の子,オンナノコ,オンナノコ
#
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
#
# !	名詞,サ変接続,*,*,*,*,!,*,*
# 隣	名詞,一般,*,*,*,*,隣,トナリ,トナリ
#
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
#
#
# ?	名詞,サ変接続,*,*,*,*,?,*,*
# 当たり前	名詞,形容動詞語幹,*,*,*,*,当たり前,アタリマエ,アタリマエ
#
# もの	名詞,非自立,一般,*,*,*,もの,モノ,モノ
# どれ	名詞,代名詞,一般,*,*,*,どれ,ドレ,ドレ
#
#
# 違っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,違う,チガッ,チガッ
#
# 見え	動詞,自立,*,*,一段,連用形,見える,ミエ,ミエ
#
# ん	名詞,非自立,一般,*,*,*,ん,ン,ン
#
# ワンツースリー	名詞,固有名詞,組織,*,*,*,ワンツースリー,*,*
# 魔法	名詞,一般,*,*,*,*,魔法,マホウ,マホー
#
# かけ	動詞,自立,*,*,一段,連用形,かける,カケ,カケ
#
# 新しい	形容詞,自立,*,*,形容詞・イ段,基本形,新しい,アタラシイ,アタラシイ
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
#
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
#
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
#
# お願い	名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ
# !	名詞,サ変接続,*,*,*,*,!,*,*
# やっぱり	副詞,一般,*,*,*,*,やっぱり,ヤッパリ,ヤッパリ
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
#
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
#
#
# あの	フィラー,*,*,*,*,*,あの,アノ,アノ
# 子	名詞,一般,*,*,*,*,子,コ,コ
# み	動詞,自立,*,*,一段,連用形,みる,ミ,ミ
#
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
#
#
# 小さく	形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,小さい,チイサク,チーサク
# 首	名詞,一般,*,*,*,*,首,クビ,クビ
#
# 傾げ	動詞,自立,*,*,一段,連用形,傾げる,カタゲ,カタゲ
#
# ボク	名詞,代名詞,一般,*,*,*,ボク,ボク,ボク
#
# 今	名詞,副詞可能,*,*,*,*,今,イマ,イマ
#
#
# シンデレラ	名詞,固有名詞,人名,一般,*,*,シンデレラ,シンデレラ,シンデレラ
# 大事	名詞,形容動詞語幹,*,*,*,*,大事,ダイジ,ダイジ
#
# 今日	名詞,副詞可能,*,*,*,*,今日,キョウ,キョー
#
# 隅っこ	名詞,一般,*,*,*,*,隅っこ,スミッコ,スミッコ
#
# 隠れ	動詞,自立,*,*,一段,連用形,隠れる,カクレ,カクレ
#
# 自分	名詞,一般,*,*,*,*,自分,ジブン,ジブン
#
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
#
# わか	動詞,自立,*,*,五段・カ行イ音便,未然形,わく,ワカ,ワカ
#
#
# なる	動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル
# 前	名詞,副詞可能,*,*,*,*,前,マエ,マエ
#
# 女の子	名詞,一般,*,*,*,*,女の子,オンナノコ,オンナノコ
#
# なり	動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ
#
# !	名詞,サ変接続,*,*,*,*,!,*,*
# お願い	名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ
# いい	形容詞,自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
#
#
# ?	名詞,サ変接続,*,*,*,*,?,*,*
# 可愛く	形容詞,自立,*,*,形容詞・イ段,連用テ接続,可愛い,カワイク,カワイク
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
#
# いい	形容詞,非自立,*,*,形容詞・イイ,基本形,いい,イイ,イイ
#
#
# ?	名詞,サ変接続,*,*,*,*,?,*,*
# ナイショ	名詞,一般,*,*,*,*,ナイショ,*,*

# %%
print(words)
# Out:
# ['ねえ', '女の子', 'なる', 'お願い', 'いい', '?', 'チョコレート', '森', 'くぐる', 'オレンジ', 'かぼちゃ', '馬車', '乗せる', 'られる', '連れる', 'られる', 'ミルク', '色', 'お', '城', 'みんな', 'きっと', '憧れる', 'いる', '童話', '中', 'ヒロイン', 'いつか', '見る', '夢', '見る', 'ガラス', 'ハイヒールナイショ', '気持ち', 'ホント', '気持ち', 'ちょっと', '話す', 'ちゃう', 'ワンツースリー', '魔法', 'かける', '新しい', 'ボク', 'なる', 'の', 'お願い', '!', 'やっぱり', 'ボク', '可愛い', 'なる', 'あの', '子', 'みる', '可愛い', 'なる', 'フリル', 'ドレス', '召す', '世界', 'ひとり', 'シンデレラ', 'ちっちゃな', 'ユウキ', 'おっきな', 'ハジメテ', 'きっと', '怖い', 'なる', '震える', 'ちゃう', '女の子', 'なる', '!', 'お願い', 'いい', '?', '可愛い', 'なる', 'いい', '?', '大人', 'なる', '下がる', '可笑しい', '声', 'トーン', '何', 'する', '何', 'する', 'うまい', 'いく', '今日', '!', '束の間', '夢', '中', 'ボク', '見つける', 'みる', '少し', '少し', '変', 'われる', '気', 'する', 'ドキドキ', 'する', 'ドキドキ', 'する', '眠れる', '夜', 'ワンツースリー', '勇気', '出す', '童話', '続く', '入口', 'もう', 'そこ', '上目遣い', '太陽', '昇る', 'ウィンク', 'ひとつ', '喧嘩', '収まる', '小さな', 'リボン', '結ぶ', '世界', 'ひとつ', 'シンデレラ', '花', '照れる', '恥ずかしい', 'がる', 'よう', 'もう少し', '君', 'ひとり占め', 'できる', 'よう', '女の子', 'なる', '!', '隣', 'いい', '?', '当たり前', 'もの', 'どれ', '違う', '見える', 'ん', 'ワンツースリー', '魔法', 'かける', '新しい', 'ボク', 'なる', 'の', 'お願い', '!', 'やっぱり', 'ボク', '可愛い', 'なる', 'あの', '子', 'みる', '可愛い', 'なる', '小さい', '首', '傾げる', 'ボク', '今', 'シンデレラ', '大事', '今日', '隅っこ', '隠れる', '自分', 'こと', 'わく', 'なる', '前', '女の子', 'なる', '!', 'お願い', 'いい', '?', '可愛い', 'なる', 'いい', '?', 'ナイショ']

# %%
import collections

count_words = collections.Counter(words)

# %%
print(count_words)
# Out:
# Counter({'なる': 15, 'いい': 6, '?': 6, 'ボク': 6, '!': 6, '可愛い': 6, 'お願い': 5, 'する': 5, '女の子': 4, 'ワンツースリー': 3, 'みる': 3, 'シンデレラ': 3, 'られる': 2, 'きっと': 2, '童話': 2, '中': 2, '見る': 2, '夢': 2, '気持ち': 2, 'ちゃう': 2, '魔法': 2, 'かける': 2, '新しい': 2, 'の': 2, 'やっぱり': 2, 'あの': 2, '子': 2, '世界': 2, '何': 2, '今日': 2, '少し': 2, 'ドキドキ': 2, 'ひとつ': 2, 'よう': 2, 'ねえ': 1, 'チョコレート': 1, '森': 1, 'くぐる': 1, 'オレンジ': 1, 'かぼちゃ': 1, '馬車': 1, '乗せる': 1, '連れる': 1, 'ミルク': 1, '色': 1, 'お': 1, '城': 1, 'みんな': 1, '憧れる': 1, 'いる': 1, 'ヒロイン': 1, 'いつか': 1, 'ガラス': 1, 'ハイヒールナイショ': 1, 'ホント': 1, 'ちょっと': 1, '話す': 1, 'フリル': 1, 'ドレス': 1, '召す': 1, 'ひとり': 1, 'ちっちゃな': 1, 'ユウキ': 1, 'おっきな': 1, 'ハジメテ': 1, '怖い': 1, '震える': 1, '大人': 1, '下がる': 1, '可笑しい': 1, '声': 1, 'トーン': 1, 'うまい': 1, 'いく': 1, '束の間': 1, '見つける': 1, '変': 1, 'われる': 1, '気': 1, '眠れる': 1, '夜': 1, '勇気': 1, '出す': 1, '続く': 1, '入口': 1, 'もう': 1, 'そこ': 1, '上目遣い': 1, '太陽': 1, '昇る': 1, 'ウィンク': 1, '喧嘩': 1, '収まる': 1, '小さな': 1, 'リボン': 1, '結ぶ': 1, '花': 1, '照れる': 1, '恥ずかしい': 1, 'がる': 1, 'もう少し': 1, '君': 1, 'ひとり占め': 1, 'できる': 1, '隣': 1, '当たり前': 1, 'もの': 1, 'どれ': 1, '違う': 1, '見える': 1, 'ん': 1, '小さい': 1, '首': 1, '傾げる': 1, '今': 1, '大事': 1, '隅っこ': 1, '隠れる': 1, '自分': 1, 'こと': 1, 'わく': 1, '前': 1, 'ナイショ': 1})

# %%
from wordcloud import WordCloud

fpath = 'C:/Windows/Fonts/YuGothM.ttc'
text = ' '.join(words)

wordcloud = WordCloud(background_color='white', font_path=fpath, width=800, height=600).generate(text)
wordcloud.to_file('./wordcloud-i_wanna_be_a_girl.png')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["font.family"] = "Yu Gothic"
plt.bar(list(count_words.keys()), list(count_words.values()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1732, in Axis.convert_units(self, x)
#    1731 try:
# -> 1732     ret = self.converter.convert(x, self.units, self)
#    1733 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[115], line 5
#       3 xs = count_words.keys()
#       4 fig,ax = plt.subplots()
# ----> 5 ax.set_xticks(xs)
#       6 # x軸のラベルを斜めにする。rotationで回転する角度
#       7 ax.set_xticklabels(xs,rotation=30)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:2074, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2071 if labels is None and kwargs:
#    2072     raise ValueError('labels argument cannot be None when '
#    2073                      'kwargs are passed')
# -> 2074 result = self._set_tick_locations(ticks, minor=minor)
#    2075 if labels is not None:
#    2076     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:2014, in Axis._set_tick_locations(self, ticks, minor)
#    2010 def _set_tick_locations(self, ticks, *, minor=False):
#    2011     # see docstring of set_ticks
#    2012
#    2013     # XXX if the user changes units, the information will be lost here
# -> 2014     ticks = self.convert_units(ticks)
#    2015     locator = mticker.FixedLocator(ticks)  # validate ticks early.
#    2016     for name, axis in self.axes._axis_map.items():
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1734, in Axis.convert_units(self, x)
#    1732     ret = self.converter.convert(x, self.units, self)
#    1733 except Exception as e:
# -> 1734     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1735                                  f'units: {x!r}') from e
#    1736 return ret
#
# ConversionError: Failed to convert value(s) to axis units: dict_keys(['ねえ', '女の子', 'なる', 'お願い', 'いい', '?', 'チョコレート', '森', 'くぐる', 'オレンジ', 'かぼちゃ', '馬車', '乗せる', 'られる', '連れる', 'ミルク', '色', 'お', '城', 'みんな', 'きっと', '憧れる', 'いる', '童話', '中', 'ヒロイン', 'いつか', '見る', '夢', 'ガラス', 'ハイヒールナイショ', '気持ち', 'ホント', 'ちょっと', '話す', 'ちゃう', 'ワンツースリー', '魔法', 'かける', '新しい', 'ボク', 'の', '!', 'やっぱり', '可愛い', 'あの', '子', 'みる', 'フリル', 'ドレス', '召す', '世界', 'ひとり', 'シンデレラ', 'ちっちゃな', 'ユウキ', 'おっきな', 'ハジメテ', '怖い', '震える', '大人', '下がる', '可笑しい', '声', 'トーン', '何', 'する', 'うまい', 'いく', '今日', '束の間', '見つける', '少し', '変', 'われる', '気', 'ドキドキ', '眠れる', '夜', '勇気', '出す', '続く', '入口', 'もう', 'そこ', '上目遣い', '太陽', '昇る', 'ウィンク', 'ひとつ', '喧嘩', '収まる', '小さな', 'リボン', '結ぶ', '花', '照れる', '恥ずかしい', 'がる', 'よう', 'もう少し', '君', 'ひとり占め', 'できる', '隣', '当たり前', 'もの', 'どれ', '違う', '見える', 'ん', '小さい', '首', '傾げる', '今', '大事', '隅っこ', '隠れる', '自分', 'こと', 'わく', '前', 'ナイショ'])
